# %%
# suppres numpy RuntimeWarning
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# # Data preparation
#
# In this tutorial we will go deeper into the different data preparation options that are possible within QSPRpred.
#
# The first step is to load the data and wrap it into a QSPRpred dataset object.
# Here we will create a regression dataset, but if you want to learn more about how to prepare
# classification data, please check the [classification tutorial](../modelling/classification.ipynb).
# If you want to know more about how to specifiy the target property,
# you can have a look at the [documentation](https://cddleiden.github.io/QSPRpred/docs/api/qsprpred.data.html#qsprpred.data.data.TargetProperty) on this topic.

# %%
import os

from qsprpred.data import QSPRDataset

os.makedirs("../../tutorial_output/data", exist_ok=True)

dataset = QSPRDataset.fromTableFile(
    filename="../../tutorial_data/hERG_Dataset.tsv",
    store_dir="../../tutorial_output/data",
    name="Preparation_hERG_Dataset",
    target_props=[{"name": "pchembl_value_Mean", "task": "REGRESSION"}],
    random_state=42
)

dataset.getDF()
# Out:
#                                                 Activity_ID Quality    source  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP_on_P0DMS8_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP_on_P29274_WT    High  ChEMBL31
# ...                                                     ...     ...       ...
# Preparation_hERG_Dataset_12435  ZXPDGTGMZKIESV_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_12436  ZXPDGTGMZKIESV_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_12437  ZYEXHNHGCDESIU_on_P0DMS8_WT    High  ChEMBL31
# Preparation_hERG_Dataset_12438  ZYQMTELMKXLVHN_on_P0DMS8_WT    High  ChEMBL31
# Preparation_hERG_Dataset_12439  ZZCFLTOMFGIFPN_on_P29275_WT    High  ChEMBL31
#
#                                                                               CID  \
# QSPRID
# Preparation_hERG_Dataset_00000                            ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00001                            ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00002                           ChEMBL31.compound.131451
# Preparation_hERG_Dataset_00003                           ChEMBL31.compound.100375
# Preparation_hERG_Dataset_00004                           ChEMBL31.compound.100375
# ...                                                                           ...
# Preparation_hERG_Dataset_12435   ChEMBL31.compound.49348;ChEMBL31.compound.413675
# Preparation_hERG_Dataset_12436   ChEMBL31.compound.49348;ChEMBL31.compound.413675
# Preparation_hERG_Dataset_12437                             ChEMBL31.compound.1825
# Preparation_hERG_Dataset_12438                            ChEMBL31.compound.18654
# Preparation_hERG_Dataset_12439  ChEMBL31.compound.425242;ChEMBL31.compound.425...
#
#                                                                            SMILES  \
# QSPRID
# Preparation_hERG_Dataset_00000  Cc1nn(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n2)c(...
# Preparation_hERG_Dataset_00001  Cc1nn(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n2)c(...
# Preparation_hERG_Dataset_00002  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2c1cc1CCCC...
# Preparation_hERG_Dataset_00003   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# Preparation_hERG_Dataset_00004   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# ...                                                                           ...
# Preparation_hERG_Dataset_12435   CNC(=O)C12CC1C(n1cnc3c1nc(Cl)nc3NC1CCCC1)C(O)C2O
# Preparation_hERG_Dataset_12436   CNC(=O)C12CC1C(n1cnc3c1nc(Cl)nc3NC1CCCC1)C(O)C2O
# Preparation_hERG_Dataset_12437       Nc1c2nc(C#Cc3ccccc3)n(C3OC(CO)C(O)C3O)c2ncn1
# Preparation_hERG_Dataset_12438  CCCn1cc2c(n1)nc(NC(=O)Nc1ccccc1OC)n1nc(-c3ccco...
# Preparation_hERG_Dataset_12439  CC1=Nc2nc3c(cccc3)n2C(c2ccco2)C1=C(O)OC(C)C(F)...
#
#                                   connectivity                     InChIKey  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ  AAEYTMMNWWKSKZ-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
# ...                                        ...                          ...
# Preparation_hERG_Dataset_12435  ZXPDGTGMZKIESV  ZXPDGTGMZKIESV-UHFFFAOYSA-N
# Preparation_hERG_Dataset_12436  ZXPDGTGMZKIESV  ZXPDGTGMZKIESV-UHFFFAOYSA-N
# Preparation_hERG_Dataset_12437  ZYEXHNHGCDESIU  ZYEXHNHGCDESIU-UHFFFAOYSA-N
# Preparation_hERG_Dataset_12438  ZYQMTELMKXLVHN  ZYQMTELMKXLVHN-UHFFFAOYSA-N
# Preparation_hERG_Dataset_12439  ZZCFLTOMFGIFPN  ZZCFLTOMFGIFPN-UHFFFAOYSA-N
#
#                                                                             InChI  \
# QSPRID
# Preparation_hERG_Dataset_00000  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00001  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00002  InChI=1S/C18H16N4O3S/c19-15-13-9-10-3-1-2-4-14...
# Preparation_hERG_Dataset_00003  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
# Preparation_hERG_Dataset_00004  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
# ...                                                                           ...
# Preparation_hERG_Dataset_12435  InChI=1S/C18H23ClN6O3/c1-20-16(28)18-6-9(18)11...
# Preparation_hERG_Dataset_12436  InChI=1S/C18H23ClN6O3/c1-20-16(28)18-6-9(18)11...
# Preparation_hERG_Dataset_12437  InChI=1S/C18H17N5O4/c19-16-13-17(21-9-20-16)23...
# Preparation_hERG_Dataset_12438  InChI=1S/C21H20N8O3/c1-3-10-28-12-13-17(26-28)...
# Preparation_hERG_Dataset_12439  InChI=1S/C19H16F3N3O3/c1-10-15(17(26)28-11(2)1...
#
#                                                                     InChI_AuxInfo  \
# QSPRID
# Preparation_hERG_Dataset_00000  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00001  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00002  "AuxInfo=1/1/N:22,23,21,24,8,15,9,14,19,20,7,1...
# Preparation_hERG_Dataset_00003  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
# Preparation_hERG_Dataset_00004  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
# ...                                                                           ...
# Preparation_hERG_Dataset_12435  "AuxInfo=1/1/N:1,22,23,21,24,6,10,20,7,12,8,25...
# Preparation_hERG_Dataset_12436  "AuxInfo=1/1/N:1,22,23,21,24,6,10,20,7,12,8,25...
# Preparation_hERG_Dataset_12437  "AuxInfo=1/1/N:11,10,12,9,13,7,6,18,26,8,17,5,...
# Preparation_hERG_Dataset_12438  "AuxInfo=1/1/N:1,22,2,17,18,28,16,19,27,3,29,5...
# Preparation_hERG_Dataset_12439  "AuxInfo=1/0/N:1,24,10,9,16,11,8,15,17,2,23,6,...
#
#                                 target_id  ... relation  \
# QSPRID                                     ...
# Preparation_hERG_Dataset_00000  P29274_WT  ...        =
# Preparation_hERG_Dataset_00001  P30542_WT  ...        =
# Preparation_hERG_Dataset_00002  P29274_WT  ...        =
# Preparation_hERG_Dataset_00003  P0DMS8_WT  ...        =
# Preparation_hERG_Dataset_00004  P29274_WT  ...        =
# ...                                   ...  ...      ...
# Preparation_hERG_Dataset_12435  P29274_WT  ...        =
# Preparation_hERG_Dataset_12436  P30542_WT  ...        =
# Preparation_hERG_Dataset_12437  P0DMS8_WT  ...        =
# Preparation_hERG_Dataset_12438  P0DMS8_WT  ...        =
# Preparation_hERG_Dataset_12439  P29275_WT  ...        =
#
#                                            pchembl_value pchembl_value_Mean  \
# QSPRID
# Preparation_hERG_Dataset_00000                      8.68              8.680
# Preparation_hERG_Dataset_00001                      6.68              6.680
# Preparation_hERG_Dataset_00002                      4.82              4.820
# Preparation_hERG_Dataset_00003                      7.15              7.150
# Preparation_hERG_Dataset_00004                      5.65              5.650
# ...                                                  ...                ...
# Preparation_hERG_Dataset_12435                 5.49;5.49              5.490
# Preparation_hERG_Dataset_12436                 7.74;7.74              7.740
# Preparation_hERG_Dataset_12437                  6.07;6.1              6.085
# Preparation_hERG_Dataset_12438            6.47;9.47;9.47              8.470
# Preparation_hERG_Dataset_12439  7.53;8.16;7.77;8.06;7.82              7.868
#
#                                pchembl_value_StdDev pchembl_value_SEM  \
# QSPRID
# Preparation_hERG_Dataset_00000             0.000000          0.000000
# Preparation_hERG_Dataset_00001             0.000000          0.000000
# Preparation_hERG_Dataset_00002             0.000000          0.000000
# Preparation_hERG_Dataset_00003             0.000000          0.000000
# Preparation_hERG_Dataset_00004             0.000000          0.000000
# ...                                             ...               ...
# Preparation_hERG_Dataset_12435             0.000000          0.000000
# Preparation_hERG_Dataset_12436             0.000000          0.000000
# Preparation_hERG_Dataset_12437             0.021213          0.015000
# Preparation_hERG_Dataset_12438             1.732051          1.000000
# Preparation_hERG_Dataset_12439             0.249139          0.111418
#
#                                 pchembl_value_N pchembl_value_Median  \
# QSPRID
# Preparation_hERG_Dataset_00000              1.0                8.680
# Preparation_hERG_Dataset_00001              1.0                6.680
# Preparation_hERG_Dataset_00002              1.0                4.820
# Preparation_hERG_Dataset_00003              1.0                7.150
# Preparation_hERG_Dataset_00004              1.0                5.650
# ...                                         ...                  ...
# Preparation_hERG_Dataset_12435              2.0                5.490
# Preparation_hERG_Dataset_12436              2.0                7.740
# Preparation_hERG_Dataset_12437              2.0                6.085
# Preparation_hERG_Dataset_12438              3.0                9.470
# Preparation_hERG_Dataset_12439              5.0                7.820
#
#                                pchembl_value_MAD  \
# QSPRID
# Preparation_hERG_Dataset_00000             0.000
# Preparation_hERG_Dataset_00001             0.000
# Preparation_hERG_Dataset_00002             0.000
# Preparation_hERG_Dataset_00003             0.000
# Preparation_hERG_Dataset_00004             0.000
# ...                                          ...
# Preparation_hERG_Dataset_12435             0.000
# Preparation_hERG_Dataset_12436             0.000
# Preparation_hERG_Dataset_12437             0.015
# Preparation_hERG_Dataset_12438             0.000
# Preparation_hERG_Dataset_12439             0.240
#
#                                                         QSPRID  \
# QSPRID
# Preparation_hERG_Dataset_00000  Preparation_hERG_Dataset_00000
# Preparation_hERG_Dataset_00001  Preparation_hERG_Dataset_00001
# Preparation_hERG_Dataset_00002  Preparation_hERG_Dataset_00002
# Preparation_hERG_Dataset_00003  Preparation_hERG_Dataset_00003
# Preparation_hERG_Dataset_00004  Preparation_hERG_Dataset_00004
# ...                                                        ...
# Preparation_hERG_Dataset_12435  Preparation_hERG_Dataset_12435
# Preparation_hERG_Dataset_12436  Preparation_hERG_Dataset_12436
# Preparation_hERG_Dataset_12437  Preparation_hERG_Dataset_12437
# Preparation_hERG_Dataset_12438  Preparation_hERG_Dataset_12438
# Preparation_hERG_Dataset_12439  Preparation_hERG_Dataset_12439
#
#                                 pchembl_value_Mean_original
# QSPRID
# Preparation_hERG_Dataset_00000                        8.680
# Preparation_hERG_Dataset_00001                        6.680
# Preparation_hERG_Dataset_00002                        4.820
# Preparation_hERG_Dataset_00003                        7.150
# Preparation_hERG_Dataset_00004                        5.650
# ...                                                     ...
# Preparation_hERG_Dataset_12435                        5.490
# Preparation_hERG_Dataset_12436                        7.740
# Preparation_hERG_Dataset_12437                        6.085
# Preparation_hERG_Dataset_12438                        8.470
# Preparation_hERG_Dataset_12439                        7.868
#
# [12440 rows x 34 columns]

# %% [markdown]
# You might have seen the preprocessing steps below in the quick_start or one of the other tutorials.
# However, there are many more preprocessing options available in QSPRpred.
#
# The `QSPRData.prepareDataset` function allows you to specify a number of preprocessing steps,
# which are then applied in a fixed order, although you can also use the individual preprocessing steps if
# you want to have more control.
#
# In this tutorial we will go through the different preprocessing steps that are available in QSPRpred.
# Some have their own dedicated tutorial, which will be linked to below.
#
# The preprocessing steps that `QSPRData.prepareDataset` applies are:
# 1. SMILES standardization
# 2. [feature calculation](descriptors.ipynb)
# 3. data filtering
# 4. fill missing feature values
# 5. [split into training and test set](data_splitting.ipynb)
# 6. feature selection
# 7. feature standardization
# 8. [outlier removal/applicability domain](applicability_domain.ipynb)

# %% [markdown]
# ## SMILES standardization
#
# The first step in the data preparation is to standardize the SMILES strings (`smiles_standardizer`).
# By default the [ChEMBL structure pipeline](https://github.com/chembl/ChEMBL_Structure_Pipeline) is used for this, but you can also specify your own function.
#
# To use the default ChEMBL structure pipeline, you can pass `"chembl"` (default), if
# you want to skip this step, you can pass None.
#
# To use your own function, you can pass a function that takes a SMILES string as input and returns a SMILES string as output.

# %%
from qsprpred.data.descriptors.fingerprints import MorganFP
from qsprpred.data.sampling.splits import RandomSplit

# custom standardizer that canonicalizes the SMILES
def custom_standardizer(smiles):
    from rdkit import Chem
    mol = Chem.MolFromSmiles(smiles)
    smiles = Chem.MolToSmiles(mol, canonical=True)
    return smiles


# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    smiles_standardizer=custom_standardizer,
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
)

dataset.getDF().head()
# Out:
#                                                 Activity_ID Quality    source  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP_on_P0DMS8_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP_on_P29274_WT    High  ChEMBL31
#
#                                                      CID  \
# QSPRID
# Preparation_hERG_Dataset_00000   ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00001   ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00002  ChEMBL31.compound.131451
# Preparation_hERG_Dataset_00003  ChEMBL31.compound.100375
# Preparation_hERG_Dataset_00004  ChEMBL31.compound.100375
#
#                                                                            SMILES  \
# QSPRID
# Preparation_hERG_Dataset_00000  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# Preparation_hERG_Dataset_00001  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# Preparation_hERG_Dataset_00002  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2nc3c(cc12...
# Preparation_hERG_Dataset_00003   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# Preparation_hERG_Dataset_00004   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
#
#                                   connectivity                     InChIKey  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ  AAEYTMMNWWKSKZ-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
#
#                                                                             InChI  \
# QSPRID
# Preparation_hERG_Dataset_00000  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00001  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00002  InChI=1S/C18H16N4O3S/c19-15-13-9-10-3-1-2-4-14...
# Preparation_hERG_Dataset_00003  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
# Preparation_hERG_Dataset_00004  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
#
#                                                                     InChI_AuxInfo  \
# QSPRID
# Preparation_hERG_Dataset_00000  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00001  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00002  "AuxInfo=1/1/N:22,23,21,24,8,15,9,14,19,20,7,1...
# Preparation_hERG_Dataset_00003  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
# Preparation_hERG_Dataset_00004  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
#
#                                 target_id  ... relation pchembl_value  \
# QSPRID                                     ...
# Preparation_hERG_Dataset_00000  P29274_WT  ...        =          8.68
# Preparation_hERG_Dataset_00001  P30542_WT  ...        =          6.68
# Preparation_hERG_Dataset_00002  P29274_WT  ...        =          4.82
# Preparation_hERG_Dataset_00003  P0DMS8_WT  ...        =          7.15
# Preparation_hERG_Dataset_00004  P29274_WT  ...        =          5.65
#
#                                pchembl_value_Mean pchembl_value_StdDev  \
# QSPRID
# Preparation_hERG_Dataset_00000               8.68                  0.0
# Preparation_hERG_Dataset_00001               6.68                  0.0
# Preparation_hERG_Dataset_00002               4.82                  0.0
# Preparation_hERG_Dataset_00003               7.15                  0.0
# Preparation_hERG_Dataset_00004               5.65                  0.0
#
#                                pchembl_value_SEM  pchembl_value_N  \
# QSPRID
# Preparation_hERG_Dataset_00000               0.0              1.0
# Preparation_hERG_Dataset_00001               0.0              1.0
# Preparation_hERG_Dataset_00002               0.0              1.0
# Preparation_hERG_Dataset_00003               0.0              1.0
# Preparation_hERG_Dataset_00004               0.0              1.0
#
#                                pchembl_value_Median pchembl_value_MAD  \
# QSPRID
# Preparation_hERG_Dataset_00000                 8.68               0.0
# Preparation_hERG_Dataset_00001                 6.68               0.0
# Preparation_hERG_Dataset_00002                 4.82               0.0
# Preparation_hERG_Dataset_00003                 7.15               0.0
# Preparation_hERG_Dataset_00004                 5.65               0.0
#
#                                                         QSPRID  \
# QSPRID
# Preparation_hERG_Dataset_00000  Preparation_hERG_Dataset_00000
# Preparation_hERG_Dataset_00001  Preparation_hERG_Dataset_00001
# Preparation_hERG_Dataset_00002  Preparation_hERG_Dataset_00002
# Preparation_hERG_Dataset_00003  Preparation_hERG_Dataset_00003
# Preparation_hERG_Dataset_00004  Preparation_hERG_Dataset_00004
#
#                                 pchembl_value_Mean_original
# QSPRID
# Preparation_hERG_Dataset_00000                         8.68
# Preparation_hERG_Dataset_00001                         6.68
# Preparation_hERG_Dataset_00002                         4.82
# Preparation_hERG_Dataset_00003                         7.15
# Preparation_hERG_Dataset_00004                         5.65
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Data filtering

# %% [markdown]
# A number of filters can be applied to the data to remove unwanted compounds.
# By default, a filter to remove duplicates is applied (`RepeatsFilter`). It removes compounds that have duplicate descriptors.
#
# A number of other filters is available in QSPRpred, which can be used by passing a list of filter objects to the `filters` argument.
# You can find all available filters in the [documentation](https://cddleiden.github.io/QSPRpred/docs/api/qsprpred.data.utils.html#module-qsprpred.data.utils.data_filters).
#
# Here, we will use the `RepeatsFilter` and the `CategoryFilter` to remove duplicates and compounds based on the value of a categorical feature.

# %%
import numpy as np

dataset.addProperty(name="FakeProperty",
                    data=np.random.choice(["Wow", "Nope"], len(dataset)))
dataset.getDF().head()
# Out:
#                                                 Activity_ID Quality    source  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP_on_P0DMS8_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP_on_P29274_WT    High  ChEMBL31
#
#                                                      CID  \
# QSPRID
# Preparation_hERG_Dataset_00000   ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00001   ChEMBL31.compound.91968
# Preparation_hERG_Dataset_00002  ChEMBL31.compound.131451
# Preparation_hERG_Dataset_00003  ChEMBL31.compound.100375
# Preparation_hERG_Dataset_00004  ChEMBL31.compound.100375
#
#                                                                            SMILES  \
# QSPRID
# Preparation_hERG_Dataset_00000  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# Preparation_hERG_Dataset_00001  Cc1cc(C)n(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n...
# Preparation_hERG_Dataset_00002  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2nc3c(cc12...
# Preparation_hERG_Dataset_00003   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# Preparation_hERG_Dataset_00004   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
#
#                                   connectivity                     InChIKey  \
# QSPRID
# Preparation_hERG_Dataset_00000  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00001  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00002  AAEYTMMNWWKSKZ  AAEYTMMNWWKSKZ-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00003  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00004  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
#
#                                                                             InChI  \
# QSPRID
# Preparation_hERG_Dataset_00000  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00001  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# Preparation_hERG_Dataset_00002  InChI=1S/C18H16N4O3S/c19-15-13-9-10-3-1-2-4-14...
# Preparation_hERG_Dataset_00003  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
# Preparation_hERG_Dataset_00004  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
#
#                                                                     InChI_AuxInfo  \
# QSPRID
# Preparation_hERG_Dataset_00000  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00001  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...
# Preparation_hERG_Dataset_00002  "AuxInfo=1/1/N:22,23,21,24,8,15,9,14,19,20,7,1...
# Preparation_hERG_Dataset_00003  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
# Preparation_hERG_Dataset_00004  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...
#
#                                 target_id  ... pchembl_value  \
# QSPRID                                     ...
# Preparation_hERG_Dataset_00000  P29274_WT  ...          8.68
# Preparation_hERG_Dataset_00001  P30542_WT  ...          6.68
# Preparation_hERG_Dataset_00002  P29274_WT  ...          4.82
# Preparation_hERG_Dataset_00003  P0DMS8_WT  ...          7.15
# Preparation_hERG_Dataset_00004  P29274_WT  ...          5.65
#
#                                pchembl_value_Mean pchembl_value_StdDev  \
# QSPRID
# Preparation_hERG_Dataset_00000               8.68                  0.0
# Preparation_hERG_Dataset_00001               6.68                  0.0
# Preparation_hERG_Dataset_00002               4.82                  0.0
# Preparation_hERG_Dataset_00003               7.15                  0.0
# Preparation_hERG_Dataset_00004               5.65                  0.0
#
#                                pchembl_value_SEM pchembl_value_N  \
# QSPRID
# Preparation_hERG_Dataset_00000               0.0             1.0
# Preparation_hERG_Dataset_00001               0.0             1.0
# Preparation_hERG_Dataset_00002               0.0             1.0
# Preparation_hERG_Dataset_00003               0.0             1.0
# Preparation_hERG_Dataset_00004               0.0             1.0
#
#                                 pchembl_value_Median pchembl_value_MAD  \
# QSPRID
# Preparation_hERG_Dataset_00000                  8.68               0.0
# Preparation_hERG_Dataset_00001                  6.68               0.0
# Preparation_hERG_Dataset_00002                  4.82               0.0
# Preparation_hERG_Dataset_00003                  7.15               0.0
# Preparation_hERG_Dataset_00004                  5.65               0.0
#
#                                                         QSPRID  \
# QSPRID
# Preparation_hERG_Dataset_00000  Preparation_hERG_Dataset_00000
# Preparation_hERG_Dataset_00001  Preparation_hERG_Dataset_00001
# Preparation_hERG_Dataset_00002  Preparation_hERG_Dataset_00002
# Preparation_hERG_Dataset_00003  Preparation_hERG_Dataset_00003
# Preparation_hERG_Dataset_00004  Preparation_hERG_Dataset_00004
#
#                                pchembl_value_Mean_original  FakeProperty
# QSPRID
# Preparation_hERG_Dataset_00000                        8.68          Nope
# Preparation_hERG_Dataset_00001                        6.68          Nope
# Preparation_hERG_Dataset_00002                        4.82          Nope
# Preparation_hERG_Dataset_00003                        7.15          Nope
# Preparation_hERG_Dataset_00004                        5.65          Nope
#
# [5 rows x 35 columns]

# %%
from qsprpred.data.processing.data_filters import RepeatsFilter, CategoryFilter

# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    data_filters=[RepeatsFilter(keep=False),
                  CategoryFilter(name="FakeProperty", values=["Wow"], keep=True)],
    # only keep compounds with FakeProperty="Wow"
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
)

dataset.getDF().head()
# Out:
#                                                 Activity_ID Quality    source  \
# QSPRID
# Preparation_hERG_Dataset_00006  AAISMSDTIOVVDP_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00007  AANFSPVRHYCMPL_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00010  AARZBDDJPFYPSG_on_P30542_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00011  AASXHCGIIQCKEE_on_P29274_WT    High  ChEMBL31
# Preparation_hERG_Dataset_00018  ABAWUOJZGIVORV_on_P29275_WT    High  ChEMBL31
#
#                                                      CID  \
# QSPRID
# Preparation_hERG_Dataset_00006   ChEMBL31.compound.72023
# Preparation_hERG_Dataset_00007  ChEMBL31.compound.387816
# Preparation_hERG_Dataset_00010   ChEMBL31.compound.20202
# Preparation_hERG_Dataset_00011  ChEMBL31.compound.419145
# Preparation_hERG_Dataset_00018  ChEMBL31.compound.466261
#
#                                                                            SMILES  \
# QSPRID
# Preparation_hERG_Dataset_00006  CCNC(=O)C1OC(n2cnc3c(Nc4ccc(OCC(=O)Nc5ccc(Cl)c...
# Preparation_hERG_Dataset_00007  N#Cc1c(N)nc(SCC2=NCCN2)c(C#N)c1-c1ccc(OCC2CC2)cc1
# Preparation_hERG_Dataset_00010  CCCCn1c(=O)[nH]c2[nH]c(-c3ccc(OCC(=O)N4CCN(Cc5...
# Preparation_hERG_Dataset_00011  CCCn1c(=O)c2c(nc3cc(OC)ccn32)n(CCCNC(=O)c2ccc(...
# Preparation_hERG_Dataset_00018              CC1=C(C(=O)OC2CCC2)C(c2ccco2)NC(=O)N1
#
#                                   connectivity                     InChIKey  \
# QSPRID
# Preparation_hERG_Dataset_00006  AAISMSDTIOVVDP  AAISMSDTIOVVDP-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00007  AANFSPVRHYCMPL  AANFSPVRHYCMPL-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00010  AARZBDDJPFYPSG  AARZBDDJPFYPSG-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00011  AASXHCGIIQCKEE  AASXHCGIIQCKEE-UHFFFAOYSA-N
# Preparation_hERG_Dataset_00018  ABAWUOJZGIVORV  ABAWUOJZGIVORV-UHFFFAOYSA-N
#
#                                                                             InChI  \
# QSPRID
# Preparation_hERG_Dataset_00006  InChI=1S/C26H26ClN7O6/c1-2-28-25(38)22-20(36)2...
# Preparation_hERG_Dataset_00007  InChI=1S/C21H20N6OS/c22-9-16-19(14-3-5-15(6-4-...
# Preparation_hERG_Dataset_00010  InChI=1S/C28H32N6O4/c1-2-3-13-34-27(36)24-26(3...
# Preparation_hERG_Dataset_00011  InChI=1S/C24H27N5O6S/c1-4-12-29-23(31)20-21(26...
# Preparation_hERG_Dataset_00018  InChI=1S/C14H16N2O4/c1-8-11(13(17)20-9-4-2-5-9...
#
#                                                                     InChI_AuxInfo  \
# QSPRID
# Preparation_hERG_Dataset_00006  "AuxInfo=1/1/N:1,2,30,33,29,34,20,36,21,35,24,...
# Preparation_hERG_Dataset_00007  "AuxInfo=1/1/N:26,27,20,29,21,28,12,13,2,16,24...
# Preparation_hERG_Dataset_00010  "AuxInfo=1/1/N:1,2,3,29,28,30,27,31,14,35,15,3...
# Preparation_hERG_Dataset_00011  "AuxInfo=1/1/N:1,14,30,2,20,26,34,27,33,15,21,...
# Preparation_hERG_Dataset_00018  "AuxInfo=1/1/N:1,9,14,8,10,13,15,2,7,12,3,11,4...
#
#                                 target_id  ... pchembl_value  \
# QSPRID                                     ...
# Preparation_hERG_Dataset_00006  P30542_WT  ...          8.51
# Preparation_hERG_Dataset_00007  P30542_WT  ...          6.32
# Preparation_hERG_Dataset_00010  P30542_WT  ...          6.91
# Preparation_hERG_Dataset_00011  P29274_WT  ...           5.2
# Preparation_hERG_Dataset_00018  P29275_WT  ...          7.02
#
#                                pchembl_value_Mean pchembl_value_StdDev  \
# QSPRID
# Preparation_hERG_Dataset_00006               8.51                  0.0
# Preparation_hERG_Dataset_00007               6.32                  0.0
# Preparation_hERG_Dataset_00010               6.91                  0.0
# Preparation_hERG_Dataset_00011               5.20                  0.0
# Preparation_hERG_Dataset_00018               7.02                  0.0
#
#                                pchembl_value_SEM pchembl_value_N  \
# QSPRID
# Preparation_hERG_Dataset_00006               0.0             1.0
# Preparation_hERG_Dataset_00007               0.0             1.0
# Preparation_hERG_Dataset_00010               0.0             1.0
# Preparation_hERG_Dataset_00011               0.0             1.0
# Preparation_hERG_Dataset_00018               0.0             1.0
#
#                                 pchembl_value_Median pchembl_value_MAD  \
# QSPRID
# Preparation_hERG_Dataset_00006                  8.51               0.0
# Preparation_hERG_Dataset_00007                  6.32               0.0
# Preparation_hERG_Dataset_00010                  6.91               0.0
# Preparation_hERG_Dataset_00011                  5.20               0.0
# Preparation_hERG_Dataset_00018                  7.02               0.0
#
#                                                         QSPRID  \
# QSPRID
# Preparation_hERG_Dataset_00006  Preparation_hERG_Dataset_00006
# Preparation_hERG_Dataset_00007  Preparation_hERG_Dataset_00007
# Preparation_hERG_Dataset_00010  Preparation_hERG_Dataset_00010
# Preparation_hERG_Dataset_00011  Preparation_hERG_Dataset_00011
# Preparation_hERG_Dataset_00018  Preparation_hERG_Dataset_00018
#
#                                pchembl_value_Mean_original  FakeProperty
# QSPRID
# Preparation_hERG_Dataset_00006                        8.51           Wow
# Preparation_hERG_Dataset_00007                        6.32           Wow
# Preparation_hERG_Dataset_00010                        6.91           Wow
# Preparation_hERG_Dataset_00011                        5.20           Wow
# Preparation_hERG_Dataset_00018                        7.02           Wow
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Filling missing features

# %% [markdown]
# After feature calculation, some features might have missing values (not relevant for Morgan fingerprints).
# By default, these are left as NaN, but you can also specify a value to fill them with.

# %%
# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    feature_fill_value=5,  # fill missing values with 5
    recalculate_features=True,
)

# %% [markdown]
# ## Feature selection

# %% [markdown]
# After feature calculation, you might want to select a subset of features to use for modelling.
# There are a number of feature selection methods available in QSPRpred, which can be used by passing a list of feature selection objects to the `feature_filters` argument.
#
# You can find an overview of available feature selection methods in the [documentation](https://cddleiden.github.io/QSPRpred/docs/api/qsprpred.data.utils.html#module-qsprpred.data.utils.featurefilters).
#
#
# Here, we will use the `HighCorrelationFilter` to remove features that are highly correlated with each other.

# %%
from qsprpred.data.processing.feature_filters import HighCorrelationFilter

# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
    feature_filters=[HighCorrelationFilter(th=0.95)]
    # remove features with correlation > 0.95
)

print(f"Number of fingerprint bits after filtering: {len(dataset.getDescriptors())}")
# Out:
# Number of fingerprint bits after filtering: 6186
# /home/s2787504/.conda/envs/qsprpred/lib/python3.13/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/s2787504/.conda/envs/qsprpred/lib/python3.13/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ## Feature standardization

# %% [markdown]
# You can also specify scikit-learn feature standardization methods to apply to the features.
# In this example we will use the scikit-learn `StandardScaler` to standardize the features.
# Note. that this is not useful for Morgan fingerprints, but we will use it here for demonstration purposes.

# %%
from qsprpred.data.processing.feature_standardizers import SKLearnStandardizer
from sklearn.preprocessing import StandardScaler

# calculate compound features and split dataset into train and test
dataset.prepareDataset(
    split=RandomSplit(test_fraction=0.2, dataset=dataset),
    feature_calculators=[MorganFP(radius=3, nBits=2048)],
    recalculate_features=True,
    feature_standardizer=SKLearnStandardizer(StandardScaler())  # standardize features
)

# %% [markdown]
# Now that you know how to use the different data preparation options, you can start preparing your own datasets.
# If you want to collect your open-source data for your own project, we recommend you check out the [data collection tutorial](data_collection_with_papyrus.ipynb). This tutorial covers how to easily collect data from [Papyrus](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-022-00672-x), a large-scale curated dataset aimed at bioactivity predictions. Of course, you can also use your own data, or data from other sources.
#
# If you have finished preparing your data set, and you are ready to start modelling, you can check out the [model assessment tutorial](model_assessment.ipynb) to learn more on how to train models in QSPRpred or the [classification tutorial](../modelling/classification.ipynb) if you want to learn more about classification modelling in QSPRpred.
